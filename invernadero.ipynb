# %% [markdown]
# # Homepage
# ![Portada del proyecto](/home/mauriciosg/iagrupo1314/Imagenes/Homepage.PNG "Portada")

# %% [markdown]
# # Images of this proyect
# ## Image of the circuit diagram made in Proteus
# ![circuit diagram](/home/mauriciosg/iagrupo1314/Imagenes/circuitdDiagram.PNG "circuit diagram")
#
# ## Image of proteus code (whatsApp)
# ![circuit source code](/home/mauriciosg/iagrupo1314/Imagenes/sourceCode.PNG "circuit source code]")
#
# ## Image of proteus code (whatsApp)
# ![Proteus and putty conection](/home/mauriciosg/iagrupo1314/Imagenes/ProteusAndPuttyConecction.PNG "Proteus and putty conectio]")
#
# ## Image of node-red
# ![Image of node-red](/home/mauriciosg/iagrupo1314/Imagenes/NodeRedImage.jpg "Image of node-red]")

# %%
# importar las librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# cargar los dataset
df = pd.read_csv("1.csv")

# %%
# Analisis preliminar del dataset
df.head()
# Out:
#    22    50    40    31    35  4.20
# 0  41  41.0  57.0  78.0  31.0   5.1
# 1  23  36.0  76.0  75.0  36.0   6.3
# 2  27  96.0  93.0  27.0  36.0   6.7
# 3  15  97.0  65.0  22.0  15.0   4.3
# 4  15  75.0  21.0  81.0  24.0   6.0

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
# ### What is Exploratory Data Analysis?
# Exploratory Data Analysis (EDA) is the first step performed by a data scientist to get a general overview of a dataset, such as its dimensions and maximum values.

# %%
# Add titles to the dataset columns
lista = ['Temperature', 'Humidity', 'Soil Humidity', 'Brightness', 'Wind', 'pH']
# Assign the list to the dataset columns
df.columns = lista
df.head()
# Out:
#    Temperature  Humidity  Soil Humidity  Brightness  Wind   pH
# 0         22.0      50.0           40.0        31.0  35.0  4.2
# 1         41.0      41.0           57.0        78.0  31.0  5.1
# 2         23.0      36.0           76.0        75.0  36.0  6.3
# 3         27.0      96.0           93.0        27.0  36.0  6.7
# 4         15.0      97.0           65.0        22.0  15.0  4.3

# %%
# Column names
df.columns
# Out:
# Index(['Temperature', 'Humidity', 'Soil Moisture', 'Luminosity', 'Wind', 'pH'], dtype='object')

# %%
# Dataset dimensions
df.shape
# Out:
# (1001, 6)

# %%
# Dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Temperature    1000 non-null   float64
#  1   Humidity       1000 non-null   float64
#  2   Soil Moisture  1000 non-null   float64
#  3   Luminosity     1000 non-null   float64
#  4   Wind           1000 non-null   float64
#  5   pH             999 non-null    float64
# dtypes: float64(6)
# memory usage: 47.0 KB

# %%
# Basic dataset statistics
df.describe()
# Out:
#        Temperature     Humidity  Soil Humidity    Brightness         Wind  \
# count  1000.000000  1000.000000    1000.000000   1000.000000  1000.000000
# mean     28.756000    64.475000      59.448000     92.095000    25.040800
# std       9.644661    21.015209      23.096639   1333.976752     9.020707
# min      12.000000     6.000000      20.000000      0.000000     3.800000
# 25%      21.000000    46.000000      40.000000     25.000000    17.000000
# 50%      28.500000    64.000000      60.000000     50.000000    25.000000
# 75%      37.000000    83.000000      79.000000     75.000000    33.000000
# max      45.000000   100.000000     100.000000  42224.000000    40.000000
#
#                pH
# count  999.000000
# mean     6.199700
# std      1.672323
# min      3.500000
# 25%      4.700000
# 50%      6.200000
# 75%      7.600000
# max      9.000000

# %%
# Method that displays the last five records of the dataset
df.tail()
# Out:
#       Temperature  Humidity  Soil Humidity  Brightness  Wind   pH
# 996          40.0      52.0           94.0        30.0  29.0  8.8
# 997          43.0      58.0           57.0        99.0  37.0  8.7
# 998          28.0      66.0           70.0        21.0  36.0  4.4
# 999          30.0      60.0           47.0        40.0  27.0  5.6
# 1000          NaN       NaN            NaN         NaN   NaN  NaN

# %% [markdown]
# # Basic central tendency statistics
# * Mean (Average)
# * Standard Deviation
# * Mode
# * Variance and Covariance
# * Maximum and Minimum
#
# ### 1. **Mean (Average)**
# The **mean** or average is the result of adding all the data points in a set and dividing the sum by the number of data points. It represents the "typical" or "central" value of a data set.
#
# - **What is it for?**: The mean is useful for getting a central reference point that summarizes the data set. It helps compare different data sets and identify overall trends.
# - **In Data Science**: The mean provides a quick overview of the average value in a data set and helps detect large deviations from the mean, such as outliers.
#
# ### 2. **Standard Deviation**
# **Standard deviation** measures how much variation or dispersion exists in a data set relative to the mean. A low standard deviation means that the data points are close to the mean, while a high standard deviation indicates more spread-out data.
#
# - **What is it for?**: It helps understand the spread of the data, showing whether the values are tightly clustered or spread out around the mean.
# - **In Data Science**: Standard deviation is crucial for measuring data volatility and assessing uncertainty or risk in predictions, such as in financial models or forecasting.
#
# ### 3. **Mode**
# **Mode** is the value that appears most frequently in a data set. Unlike the mean, mode is useful when there are repeated values, and there can be more than one mode if multiple values occur with the same frequency.
#
# - **What is it for?**: It’s useful for identifying the most frequent value, especially in categorical data. It can highlight the most common behavior in the data.
# - **In Data Science**: Mode is used to analyze frequent patterns in discrete or categorical data, such as user preferences or consumer behavior.
#
# ### 4. **Variance and Covariance**
# - **Variance**: This is the average of the squared differences between each data point and the mean. It’s a measure of dispersion like standard deviation, but expressed in squared units.
#
#   - **What is it for?**: It measures data variability. The higher the variance, the greater the spread of data around the mean.
#
# - **Covariance**: This measures how two variables change together. A positive covariance means that when one variable increases, the other tends to increase as well. A negative covariance means that when one increases, the other tends to decrease.
#
#   - **What is it for?**: It helps identify relationships between two variables. A covariance close to zero indicates no linear relationship between the variables.
#
# - **In Data Science**: Covariance is key in correlation analysis and building predictive models, where it’s important to understand how variables vary together. Variance is essential for evaluating data uncertainty and consistency.
#
# ### 5. **Maximum and Minimum**
# - **Maximum**: The highest value in a data set.
# - **Minimum**: The lowest value in a data set.
#
# - **What is it for?**: To identify the extreme values or limits in the data. Maximums and minimums are useful for understanding the range of the data.
# - **In Data Science**: They help identify outliers and define data limits for normalization or scaling, which is common in data preprocessing before applying machine learning algorithms.
#
# ### In summary:
# These measures provide essential information about the **distribution** and **relationships** in data. In **Data Science**, they are used to analyze trends, detect anomalies, build predictive models, and make data-driven decisions.

# %% [markdown]
# # Measures of central tendency for the dataset 1.csv

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Load the dataset
df = pd.read_csv("1.csv")

# Add titles to the dataset columns
list = ['Temperature', 'Humidity', 'Soil Humidity', 'Luminosity', 'Wind', 'Ph']
# Assign the list to the dataset columns
df.columns = list
df.head()
# Out:
#   Temperature  Humidity  Soil Humidity  Luminosity  Wind   Ph
# 0          41      41.0           57.0        78.0  31.0  5.1
# 1          23      36.0           76.0        75.0  36.0  6.3
# 2          27      96.0           93.0        27.0  36.0  6.7
# 3          15      97.0           65.0        22.0  15.0  4.3
# 4          15      75.0           21.0        81.0  24.0  6.0

# %%
# Define the columns
columns = ['Temperature', 'Humidity', 'Soil Humidity', 'Luminosity', 'Wind', 'Ph']

# Central tendency measures for each column
for col in columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')  # Convert to numeric
    print(f"\n--- {col} ---")
    print(f"Mean: {df[col].mean():.2f}")
    print(f"Std: {df[col].std():.2f}")
    print(f"Mode: {df[col].mode().tolist()}")
    print(f"Min: {df[col].min():.2f}")
    print(f"Max: {df[col].max():.2f}")

# Calculate the covariance between the columns
cov_matrix = df[columns].cov()
print("\n--- Covariance Matrix ---")
print(cov_matrix)

# Plot histograms for each column
for col in columns:
    plt.figure(figsize=(8, 6))
    plt.hist(df[col].dropna(), bins=10, color='blue', alpha=0.7)  # Drop NaN values for the histogram
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()
# Out:
# --- Temperature ---
# Mean: 28.76
# Std: 9.65
# Mode: [31.0]
# Min: 12.00
# Max: 45.00
#
# --- Humidity ---
# Mean: 64.49
# Std: 21.02
# Mode: [50.0]
# Min: 6.00
# Max: 100.00
#
# --- Soil Humidity ---
# Mean: 59.47
# Std: 23.10
# Mode: [21.0]
# Min: 20.00
# Max: 100.00
#
# --- Luminosity ---
# Mean: 92.16
# Std: 1334.64
# Mode: [90.0]
# Min: 0.00
# Max: 42224.00
#
# --- Wind ---
# Mean: 25.03
# Std: 9.02
# Mode: [37.0]
# Min: 3.80
# Max: 40.00
#
# --- Ph ---
# Mean: 6.20
# Std: 1.67
# Mode: [4.2]
# Min: 3.50
# Max: 9.00
#
# --- Covariance Matrix ---
#                Temperature    Humidity  Soil Humidity    Luminosity  \
# Temperature      93.066909    3.217444      -1.491193 -1.549379e+02
# Humidity          3.217444  441.871382     -32.923438 -7.052348e+02
# Soil Humidity    -1.491193  -32.923438     533.609913  1.335335e+03
# Luminosity     -154.937867 -705.234830    1335.334745  1.781273e+06
# Wind             -1.427749   -0.733343      -1.584768 -8.962718e+02
# ...

# %% [markdown]
# # Measures of central tendency for the dataset 2.csv

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Load the dataset
df = pd.read_csv("2.csv")

# Add titles to the dataset columns
list = ['Temperature', 'Humidity', 'Soil Humidity', 'Luminosity', 'Wind', 'Ph']
# Assign the list to the dataset columns
df.columns = list
df.head()
# Out:
#   Temperature  Humidity  Soil Humidity  Luminosity  Wind   Ph
# 0          15      74.0           69.0        39.0  20.0  8.7
# 1          18      93.0           48.0         9.0  28.0  6.9
# 2          26      90.0           37.0        72.0  39.0  4.9
# 3          16      60.0           69.0        73.0  28.0  8.6
# 4          40      33.0           43.0        90.0  17.0  6.9

# %%
# Define the columns
columns = ['Temperature', 'Humidity', 'Soil Humidity', 'Luminosity', 'Wind', 'Ph']

# Central tendency measures for each column
for col in columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')  # Convert to numeric
    print(f"\n--- {col} ---")
    print(f"Mean: {df[col].mean():.2f}")
    print(f"Std: {df[col].std():.2f}")
    print(f"Mode: {df[col].mode().tolist()}")
    print(f"Min: {df[col].min():.2f}")
    print(f"Max: {df[col].max():.2f}")

# Calculate the covariance between the columns
cov_matrix = df[columns].cov()
print("\n--- Covariance Matrix ---")
print(cov_matrix)

# Plot histograms for each column
for col in columns:
    plt.figure(figsize=(8, 6))
    plt.hist(df[col].dropna(), bins=10, color='blue', alpha=0.7)  # Drop NaN values for the histogram
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()
# Out:
# --- Temperature ---
# Mean: 28.80
# Std: 10.01
# Mode: [45.0]
# Min: 12.00
# Max: 45.00
#
# --- Humidity ---
# Mean: 64.61
# Std: 21.01
# Mode: [30.0, 44.0]
# Min: 30.00
# Max: 100.00
#
# --- Soil Humidity ---
# Mean: 58.81
# Std: 23.44
# Mode: [96.0]
# Min: 20.00
# Max: 100.00
#
# --- Luminosity ---
# Mean: 48.94
# Std: 28.45
# Mode: [73.0]
# Min: 0.00
# Max: 100.00
#
# --- Wind ---
# Mean: 24.73
# Std: 9.00
# Mode: [28.0]
# Min: 10.00
# Max: 40.00
#
# --- Ph ---
# Mean: 6.23
# Std: 1.64
# Mode: [5.8, 8.6]
# Min: 3.50
# Max: 9.00
#
# --- Covariance Matrix ---
#                Temperature    Humidity  Soil Humidity  Luminosity       Wind  \
# Temperature     100.161478    8.367066      -0.883782   12.043348   0.108420
# Humidity          8.367066  441.595800       4.677208  -22.683213  -6.290462
# Soil Humidity    -0.883782    4.677208     549.397415  -11.999856   4.140282
# Luminosity       12.043348  -22.683213     -11.999856  809.155338  -2.715521
# ...

# %% [markdown]
# # Measures of central tendency for the dataset 3.csv

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Load the dataset
df = pd.read_csv("3.csv")

# Add titles to the dataset columns
list = ['Temperature', 'Humidity', 'Soil Humidity', 'Luminosity', 'Wind', 'Ph']
# Assign the list to the dataset columns
df.columns = list
df.head()
# Out:
#   Temperature  Humidity  Soil Humidity  Luminosity  Wind   Ph
# 0          21      96.0           70.0        42.0  10.0  8.5
# 1          38      50.0           30.0        64.0  36.0  8.6
# 2          33      65.0           86.0         7.0  38.0  8.4
# 3          27      91.0           53.0        25.0  37.0  7.6
# 4          29      86.0           95.0        68.0  21.0  5.8

# %%
# Define the columns
columns = ['Temperature', 'Humidity', 'Soil Humidity', 'Luminosity', 'Wind', 'Ph']

# Central tendency measures for each column
for col in columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')  # Convert to numeric
    print(f"\n--- {col} ---")
    print(f"Mean: {df[col].mean():.2f}")
    print(f"Std: {df[col].std():.2f}")
    print(f"Mode: {df[col].mode().tolist()}")
    print(f"Min: {df[col].min():.2f}")
    print(f"Max: {df[col].max():.2f}")

# Calculate the covariance between the columns
cov_matrix = df[columns].cov()
print("\n--- Covariance Matrix ---")
print(cov_matrix)

# Plot histograms for each column
for col in columns:
    plt.figure(figsize=(8, 6))
    plt.hist(df[col].dropna(), bins=10, color='blue', alpha=0.7)  # Drop NaN values for the histogram
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()
# Out:
# --- Temperature ---
# Mean: 27.93
# Std: 10.04
# Mode: [19.0]
# Min: 12.00
# Max: 45.00
#
# --- Humidity ---
# Mean: 64.17
# Std: 20.52
# Mode: [46.0, 89.0]
# Min: 30.00
# Max: 100.00
#
# --- Soil Humidity ---
# Mean: 59.88
# Std: 23.11
# Mode: [59.0, 70.0]
# Min: 20.00
# Max: 100.00
#
# --- Luminosity ---
# Mean: 49.92
# Std: 29.15
# Mode: [4.0]
# Min: 0.00
# Max: 100.00
#
# --- Wind ---
# Mean: 24.98
# Std: 8.96
# Mode: [19.0]
# Min: 10.00
# Max: 40.00
#
# --- Ph ---
# Mean: 6.31
# Std: 1.62
# Mode: [8.5]
# Min: 3.50
# Max: 9.00
#
# --- Covariance Matrix ---
#                Temperature    Humidity  Soil Humidity  Luminosity       Wind  \
# Temperature     100.843922    1.019056      10.096836   -7.331913  -1.533241
# Humidity          1.019056  421.234162     -12.082089  -14.206175   7.290542
# Soil Humidity    10.096836  -12.082089     534.132610   21.172139  -9.095250
# Luminosity       -7.331913  -14.206175      21.172139  849.873966  -5.561416
# ...

# %% [markdown]
# # Measures of central tendency for the dataset 4.csv

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Load the dataset
df = pd.read_csv("4.csv")

# Add titles to the dataset columns
list = ['Temperature', 'Humidity', 'Soil Humidity', 'Luminosity', 'Wind', 'Ph']
# Assign the list to the dataset columns
df.columns = list
df.head()
# Out:
#   Temperature  Humidity  Soil Humidity  Luminosity  Wind   Ph
# 0          13      69.0           53.0        38.0  34.0  7.4
# 1          31      47.0           27.0        80.0  35.0  8.2
# 2          35      51.0           69.0        71.0  19.0  6.6
# 3          38      39.0           36.0        21.0  15.0  4.2
# 4          30      84.0           20.0        19.0  26.0  5.4

# %%
# Define the columns
columns = ['Temperature', 'Humidity', 'Soil Humidity', 'Luminosity', 'Wind', 'Ph']

# Central tendency measures for each column
for col in columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')  # Convert to numeric
    print(f"\n--- {col} ---")
    print(f"Mean: {df[col].mean():.2f}")
    print(f"Std: {df[col].std():.2f}")
    print(f"Mode: {df[col].mode().tolist()}")
    print(f"Min: {df[col].min():.2f}")
    print(f"Max: {df[col].max():.2f}")

# Calculate the covariance between the columns
cov_matrix = df[columns].cov()
print("\n--- Covariance Matrix ---")
print(cov_matrix)

# Plot histograms for each column
for col in columns:
    plt.figure(figsize=(8, 6))
    plt.hist(df[col].dropna(), bins=10, color='blue', alpha=0.7)  # Drop NaN values for the histogram
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()
# Out:
# --- Temperature ---
# Mean: 68.25
# Std: 1257.47
# Mode: [26.0]
# Min: 12.00
# Max: 39772.00
#
# --- Humidity ---
# Mean: 64.72
# Std: 20.68
# Mode: [30.0]
# Min: 30.00
# Max: 100.00
#
# --- Soil Humidity ---
# Mean: 60.13
# Std: 23.71
# Mode: [47.0]
# Min: 20.00
# Max: 100.00
#
# --- Luminosity ---
# Mean: 51.75
# Std: 29.29
# Mode: [80.0, 99.0]
# Min: 0.00
# Max: 100.00
#
# --- Wind ---
# Mean: 24.78
# Std: 8.85
# Mode: [19.0]
# Min: 3.70
# Max: 40.00
#
# --- Ph ---
# Mean: 6.28
# Std: 1.64
# Mode: [9.0]
# Min: 3.50
# Max: 9.00
#
# --- Covariance Matrix ---
#                 Temperature     Humidity  Soil Humidity   Luminosity  \
# Temperature    1.581221e+06 -1258.558689   -1603.729257 -1088.898997
# Humidity      -1.258559e+03   427.533261     -27.160552    10.983479
# Soil Humidity -1.603729e+03   -27.160552     562.252848    10.181257
# Luminosity    -1.088899e+03    10.983479      10.181257   857.801533
# Wind          -8.409208e+02     1.216672      -9.155735    -9.880377
# ...

# %% [markdown]
# # Measures of central tendency for the dataset 5.csv

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Load the dataset
df = pd.read_csv("5.csv")

# Add titles to the dataset columns
list = ['Temperature', 'Humidity', 'Soil Humidity', 'Luminosity', 'Wind', 'Ph']
# Assign the list to the dataset columns
df.columns = list
df.head()
# Out:
#   Temperature  Humidity  Soil Humidity  Luminosity  Wind   Ph
# 0          15      74.0           69.0        39.0  20.0  8.7
# 1          18      93.0           48.0         9.0  28.0  6.9
# 2          26      90.0           37.0        72.0  39.0  4.9
# 3          16      60.0           69.0        73.0  28.0  8.6
# 4          40      33.0           43.0        90.0  17.0  6.9

# %%
# Define the columns
columns = ['Temperature', 'Humidity', 'Soil Humidity', 'Luminosity', 'Wind', 'Ph']

# Central tendency measures for each column
for col in columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')  # Convert to numeric
    print(f"\n--- {col} ---")
    print(f"Mean: {df[col].mean():.2f}")
    print(f"Std: {df[col].std():.2f}")
    print(f"Mode: {df[col].mode().tolist()}")
    print(f"Min: {df[col].min():.2f}")
    print(f"Max: {df[col].max():.2f}")

# Calculate the covariance between the columns
cov_matrix = df[columns].cov()
print("\n--- Covariance Matrix ---")
print(cov_matrix)

# Plot histograms for each column
for col in columns:
    plt.figure(figsize=(8, 6))
    plt.hist(df[col].dropna(), bins=10, color='blue', alpha=0.7)  # Drop NaN values for the histogram
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()
# Out:
# --- Temperature ---
# Mean: 28.80
# Std: 10.01
# Mode: [45.0]
# Min: 12.00
# Max: 45.00
#
# --- Humidity ---
# Mean: 64.61
# Std: 21.01
# Mode: [30.0, 44.0]
# Min: 30.00
# Max: 100.00
#
# --- Soil Humidity ---
# Mean: 58.81
# Std: 23.44
# Mode: [96.0]
# Min: 20.00
# Max: 100.00
#
# --- Luminosity ---
# Mean: 48.94
# Std: 28.45
# Mode: [73.0]
# Min: 0.00
# Max: 100.00
#
# --- Wind ---
# Mean: 24.73
# Std: 9.00
# Mode: [28.0]
# Min: 10.00
# Max: 40.00
#
# --- Ph ---
# Mean: 6.23
# Std: 1.64
# Mode: [5.8, 8.6]
# Min: 3.50
# Max: 9.00
#
# --- Covariance Matrix ---
#                Temperature    Humidity  Soil Humidity  Luminosity       Wind  \
# Temperature     100.161478    8.367066      -0.883782   12.043348   0.108420
# Humidity          8.367066  441.595800       4.677208  -22.683213  -6.290462
# Soil Humidity    -0.883782    4.677208     549.397415  -11.999856   4.140282
# Luminosity       12.043348  -22.683213     -11.999856  809.155338  -2.715521
# ...

# %% [markdown]
# # Creación del dataset 6

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Cargar los cinco datasets
df1 = pd.read_csv('1.csv')
df2 = pd.read_csv('2.csv')
df3 = pd.read_csv('3.csv')
df4 = pd.read_csv('4.csv')
df5 = pd.read_csv('5.csv')

column_names = ['Temperatura', 'Humedad', 'Humedad del terreno', 'Luminosidad', 'Viento', 'Ph']
df1.columns = column_names
df2.columns = column_names
df3.columns = column_names
df4.columns = column_names
df5.columns = column_names

# Fusionar los cinco datasets en uno solo
combined_df = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)

# Ver las primeras filas del conjunto de datos fusionado
combined_df.head()
# Out:
#   Temperatura  Humedad  Humedad del terreno  Luminosidad  Viento   Ph
# 0          41     41.0                 57.0         78.0    31.0  5.1
# 1          23     36.0                 76.0         75.0    36.0  6.3
# 2          27     96.0                 93.0         27.0    36.0  6.7
# 3          15     97.0                 65.0         22.0    15.0  4.3
# 4          15     75.0                 21.0         81.0    24.0  6.0

# %%
print(df1.columns)
print(df2.columns)
print(df3.columns)
print(df4.columns)
print(df5.columns)
# Out:
# Index(['Temperatura', 'Humedad', 'Humedad del terreno', 'Luminosidad',
#        'Viento', 'Ph'],
#       dtype='object')
# Index(['Temperatura', 'Humedad', 'Humedad del terreno', 'Luminosidad',
#        'Viento', 'Ph'],
#       dtype='object')
# Index(['Temperatura', 'Humedad', 'Humedad del terreno', 'Luminosidad',
#        'Viento', 'Ph'],
#       dtype='object')
# Index(['Temperatura', 'Humedad', 'Humedad del terreno', 'Luminosidad',
#        'Viento', 'Ph'],
#       dtype='object')
# Index(['Temperatura', 'Humedad', 'Humedad del terreno', 'Luminosidad',
#        'Viento', 'Ph'],
#       dtype='object')

# %%
# Exploratory analysis: Measures of central tendency
for column in combined_df.select_dtypes(include=['float64', 'int64']).columns:
    print(f'--- {column} ---')
    print(f"Mean: {combined_df[column].mean()}")
    print(f"Median: {combined_df[column].median()}")
    print(f"Mode: {combined_df[column].mode()[0]}")
    print(f"Min: {combined_df[column].min()}")
    print(f"Max: {combined_df[column].max()}")
    print()

# Exploratory analysis: Measures of dispersion
for column in combined_df.select_dtypes(include=['float64', 'int64']).columns:
    print(f'--- {column} ---')
    print(f"Range: {combined_df[column].max() - combined_df[column].min()}")
    print(f"Standard Deviation: {combined_df[column].std()}")
    print(f"Variance: {combined_df[column].var()}")
    Q1 = combined_df[column].quantile(0.25)
    Q3 = combined_df[column].quantile(0.75)
    IQR = Q3 - Q1
    print(f"Interquartile Range (IQR): {IQR}")
    CV = (combined_df[column].std() / combined_df[column].mean()) * 100
    print(f"Coefficient of Variation (CV): {CV}%")
    print()

# Limpieza de NaN antes de graficar los box plots
for column in combined_df.select_dtypes(include=['float64', 'int64']).columns:
    plt.figure()
    
    # Eliminar los valores NaN para el boxplot
    clean_data = combined_df[column].dropna()
    
    # Verificar si hay datos suficientes después de eliminar NaNs
    if not clean_data.empty:
        plt.boxplot(clean_data, vert=False)
        plt.title(f'Box plot of {column}')
        plt.xlabel(column)
        plt.grid(True)
        plt.show()
    else:
        print(f"No hay suficientes datos en la columna {column} después de eliminar NaN.")

# Plot histograms for numerical columns
for column in combined_df.select_dtypes(include=['float64', 'int64']).columns:
    plt.figure()
    plt.hist(combined_df[column], bins=10, color='blue', alpha=0.7)
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()
# Out:
# --- Humedad ---
# Mean: 64.51951951951952
# Median: 64.0
# Mode: 30.0
# Min: 6.0
# Max: 100.0
#
# --- Humedad del terreno ---
# Mean: 59.41981981981982
# Median: 59.0
# Mode: 86.0
# Min: 20.0
# Max: 100.0
#
# --- Luminosidad ---
# Mean: 58.34134134134134
# Median: 50.0
# Mode: 73.0
# Min: 0.0
# Max: 42224.0
#
# --- Viento ---
# Mean: 24.84994994994995
# Median: 25.0
# Mode: 19.0
# Min: 3.7
# Max: 40.0
#
# --- Ph ---
# Mean: 6.2507911075505715
# Median: 6.2
# Mode: 5.5
# Min: 3.5
# Max: 9.0
#
# --- Humedad ---
# Range: 94.0
# Standard Deviation: 20.843538881511833
# Variance: 434.4531131050955
# Interquartile Range (IQR): 37.0
# Coefficient of Variation (CV): 32.30578751474722%
#
# --- Humedad del terreno ---
# Range: 80.0
# Standard Deviation: 23.358340310090913
# Variance: 545.612062042018
# Interquartile Range (IQR): 41.0
# Coefficient of Variation (CV): 39.31068855631165%
#
# --- Luminosidad ---
# Range: 42224.0
# Standard Deviation: 597.4286167779183
# ...
